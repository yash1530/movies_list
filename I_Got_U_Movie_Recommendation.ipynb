# %% [markdown]
# # installing all the required libraries we need in this movie recommendation

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas as
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 1.1 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 633.8 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
# 1.NumPy stands for Numerical Python 2.In Python we have lists that serve the purpose of arrays, but they are slow to process.
#NumPy aims to provide an array object that is up to 50x faster than traditional Python lists.
#he array xobject in NumPy is called ndarray, it provides a lot of supporting functions that make working with ndarray very easy.
import pandas as pd
#Pandas is a Python library used for working with data sets
#to import and manipulate  and read data sets we use the pandas.
import difflib
#get close matches eg: if we enter any wrong name it will recommeds the relatable words.
from sklearn.metrics.pairwise  import cosine_similarity
#cosine similarity - we use to sepatarte the movies based on the cosine simillarity.those movies having highest similarity we recommed to the user 
from sklearn.feature_extraction.text import TfidfVectorizer
#string data to the  numperical data we use feature_extraction.

# %% [markdown]
# ## reading the file is important we have to read our csv file we must downlaod the file and must import into our jupyter files we may face some erros handle it carefully.

# %%
movies_data=pd.read_csv('movies.csv')

# %% [markdown]
# ## head represents the top 5 rows of the data

# %%
movies_data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %% [markdown]
# # tail represents the bottom rows of the data

# %%
movies_data.tail()
# Out:
#       index  budget                         genres  \
# 4798   4798  220000          Action Crime Thriller
# 4799   4799    9000                 Comedy Romance
# 4800   4800       0  Comedy Drama Romance TV Movie
# 4801   4801       0                            NaN
# 4802   4802       0                    Documentary
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  united states\u2013mexico barrier legs arms pa...                es
# 4799                                                NaN                en
# ...

# %% [markdown]
# # shape represents the number of columns and the rows in the data

# %%
movies_data.shape
# Out:
# (4803, 24)

# %% [markdown]
# ### i am going to use only selected colums from data.

# %%
selected_list=['genres','keywords','tagline','original_title','cast','director']
print(selected_list)
# Out:
# ['genres', 'keywords', 'tagline', 'original_title', 'cast', 'director']

# %% [markdown]
# ## replacing null values in selected list

# %%
# if there are any missing values we have to replace with the null vlaues.
for i in selected_list:
    movies_data[i]=movies_data[i].fillna('')

# %% [markdown]
# ## combing all the selected features

# %%
combine_data=movies_data['original_title']+' '+movies_data['genres']+' '+movies_data['keywords']+' '+movies_data['tagline']+' '+movies_data['cast']+' '+movies_data['director']

# %%
print(combine_data)
# Out:
# 0       Avatar Action Adventure Fantasy Science Fictio...
# 1       Pirates of the Caribbean: At World's End Adven...
# 2       Spectre Action Adventure Crime spy based on no...
# 3       The Dark Knight Rises Action Crime Drama Thril...
# 4       John Carter Action Adventure Science Fiction b...
#                               ...
# 4798    El Mariachi Action Crime Thriller united state...
# 4799    Newlyweds Comedy Romance  A newlywed couple's ...
# 4800    Signed, Sealed, Delivered Comedy Drama Romance...
# 4801    Shanghai Calling   A New Yorker in Shanghai Da...
# 4802    My Date with Drew Documentary obsession camcor...
# Length: 4803, dtype: object

# %% [markdown]
# ### we are converting the text data into the numericals beacause our cosine similarity is simple to caluculate with the numerical data

# %%
#TfidfVectorizer tf-term frequency and idf-iverse document frequency
#tf =no of times term (t)  appered in the document/no of total terms i the document is the term frequency.
#idf=log(N/n)
#N = number of documents n=number of documents i which our t appers.
#for rare word the idf is high and frequent word my idf value is low.
vectorizer=TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(combine_data)
print(feature_vectors)
# Out:
#   (0, 2744)	0.16772473560406084
#   (0, 8721)	0.10946077894235717
#   (0, 14533)	0.1886141774400334
#   (0, 11377)	0.15593878194560065
#   (0, 9786)	0.22051719575406448
#   (0, 16313)	0.147121469825049
#   (0, 18641)	0.19268914829880274
#   (0, 15678)	0.19999951254731108
#   (0, 14852)	0.21144452063080932
#   (0, 19313)	0.19494276097382635
#   (0, 19009)	0.22958987087731966
#   (0, 14884)	0.1456194164939141
#   (0, 12816)	0.25516430565755777
#   (0, 12464)	0.0765980111781902
#   (0, 18999)	0.12186197978093309
#   (0, 17050)	0.05465602623185054
#   (0, 5563)	0.22051719575406448
#   (0, 15923)	0.20440720707953625
#   (0, 3616)	0.2423770882674387
#   (0, 18550)	0.12073149464075264
#   (0, 16045)	0.3262922150896951
#   (0, 6578)	0.15877549374414104
#   (0, 3437)	0.2156557213278607
#   (0, 4135)	0.20772997836394544
#   (0, 6110)	0.10052433365738404
#   :	:
#   (4801, 7790)	0.25681453914282587
#   (4801, 12988)	0.19182575465913015
#   (4801, 1898)	0.1383708841183607
# ...

# %% [markdown]
# ## cosine similarity

# %%
#now we will strore all the similar scores.
#how cosine similarity works.
#the each movie check with all the movies in the data and it will produce the similirity score.
similarity=cosine_similarity(feature_vectors)
print(similarity)
# Out:
# [[1.         0.07355546 0.03531556 ... 0.         0.         0.        ]
#  [0.07355546 1.         0.02790734 ... 0.04430756 0.         0.        ]
#  [0.03531556 0.02790734 1.         ... 0.         0.04635788 0.        ]
#  ...
#  [0.         0.04430756 0.         ... 1.         0.         0.05548941]
#  [0.         0.         0.04635788 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.05548941 0.         1.        ]]

# %%
similarity.shape
# Out:
# (4803, 4803)

# %%
#getting the movie name from the user
movie_name=input('enter your movie name champ: ')
# Out:
# enter your movie name champ: iron man

# %%
#creating a list with all the movies given in the list
#selectint the titl column int the data.
title_list=movies_data['title']
#converting into list of movies.
title_list=movies_data['title'].tolist()
print(title_list)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
#find the close match.
find_close_match=difflib.get_close_matches(movie_name,title_list)
print(find_close_match)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
#best close match
close_match=find_close_match[0]
print(close_match)
# Out:
# Iron Man

# %%
index_of_the_movie=movies_data[movies_data.title==close_match]['index'].values[0]
#for geeting the actual index we will use values[0].bcz the data is in the form list for getting exact index we are using it.
print(index_of_the_movie)
# Out:
# 68

# %%
#geting the similar movies 
similarity_score=list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
#first value is index and second value is the
# Out:
# [(0, 0.03177463723388234), (1, 0.04648940505655183), (2, 0.012933720086446351), (3, 0.005792646858257661), (4, 0.031625775429261545), (5, 0.028377299964838433), (6, 0.07166579690124981), (7, 0.20871556897011054), (8, 0.006973204563376672), (9, 0.06604813017652703), (10, 0.06866178975551764), (11, 0.011027406284347029), (12, 0.025705343298299863), (13, 0.01104365028126098), (14, 0.11894463273567028), (15, 0.006419786642082926), (16, 0.21437378046318104), (17, 0.011508511491314795), (18, 0.03909164309643928), (19, 0.06942993142070154), (20, 0.0879500167257875), (21, 0.01040540410792756), (22, 0.005634567710253561), (23, 0.005580717537824117), (24, 0.011987457533441666), (25, 0.0), (26, 0.1847009163822431), (27, 0.029271799816630355), (28, 0.057604822381483914), (29, 0.013166070754680431), (30, 0.09186570700092811), (31, 0.3587552100060593), (32, 0.024428458675532182), (33, 0.11866110669018584), (34, 0.0), (35, 0.030995117944996327), (36, 0.02628799343128408), (37, 0.0069500112213550114
# ...

# %%
#len of the similarity score
len(similarity_score)

# %%
#sorting the movies based on higher similarity score
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1],reverse=True)
print(sorted_similar_movies)
# Out:
# [(68, 1.0000000000000002), (79, 0.4557842249390144), (31, 0.3587552100060593), (16, 0.21437378046318104), (7, 0.20871556897011054), (182, 0.1978626601879218), (26, 0.1847009163822431), (85, 0.18281977545618888), (511, 0.16121027958930437), (3623, 0.1537844031455292), (64, 0.1444219618209891), (203, 0.14076351591689798), (174, 0.1383460087285211), (101, 0.13439460849558169), (788, 0.12656448055944627), (1740, 0.12550023101807672), (46, 0.12523570300845838), (94, 0.12424466260653502), (126, 0.12387883456767687), (169, 0.12364592305527476), (131, 0.12363176701979717), (14, 0.11894463273567028), (33, 0.11866110669018584), (38, 0.11827381158948116), (2487, 0.11644117477707143), (783, 0.11477816797793379), (138, 0.11018910305237287), (661, 0.109789140318127), (2651, 0.10797211398256212), (3166, 0.1066825528367738), (2442, 0.10553097988425966), (353, 0.10540592500108781), (870, 0.1053887447266095), (1553, 0.10337856752960972), (607, 0.10211053580231302), (1451, 0.10139141722196646), (2411, 
# ...

# %%
#print the similar movies based on the index
print("the suggested movies are")
i=0
for movie in sorted_similar_movies:
    index=movie[0]
    title_from_index=movies_data[movies_data.index ==index]['title'].values[0]
    if(i<30):
        print(i,'.',title_from_index)
    else:
        break
    i+=1;

# %%
#movie recomendation system
movie_name = input(' Enter your favourite movie name : ')

list_of_all_titles = movies_data['title'].tolist()

find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)

close_match = find_close_match[0]

index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]

similarity_score = list(enumerate(similarity[index_of_the_movie]))

sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True) 

print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<30):
    print(i, '.',title_from_index)
    i+=1
# Out:
#  Enter your favourite movie name : bat man
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #movie recomendation system
#       2 movie_name = input(' Enter your favourite movie name : ')
# ----> 4 list_of_all_titles = movies_data['title'].tolist()
#       6 find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
#       8 close_match = find_close_match[0]
#
# NameError: name 'movies_data' is not defined
